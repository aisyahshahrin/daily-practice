# %%
print('welcome aisyah to Pyhton')
# Out:
# welcome aisyah to Pyhton

# %%
print('do less get more')
# Out:
# do less get more

# %%
print('10+5')
# Out:
# 10+5

# %%
#input example
username=input ('Enter Username')
print('welcome to the world Mr./Mrs.:' + username)
# Out:
# Enter Usernameamir
# welcome to the world Mr./Mrs.:amir

# %%
num1=12
num2=25
result=num1+num2
print(result)
# Out:
# 37

# %%
print(f'first number {num1} and secound number {num2} Result: {result}')
# Out:
# first number 12 and secound number 25 Result: 37

# %%
fnum= (input('enter first number'))
snum=(input('enter secound number'))
result=fnum+snum
print (f'Result after adding {fnum} and {snum} is =\t {result}')
# Out:
# enter first number12
# enter secound number25
# Result after adding 12 and 25 is =	 1225

# %%
fnum=int(input('enter first number'))
snum=int(input('enter secound number'))
result=fnum+snum
print (f'Result after adding {fnum} and {snum} is =\t {result}')
# Out:
# enter first number12
# enter secound number25
# Result after adding 12 and 25 is =	 37

# %%
type({})
# Out:
# dict

# %%
num=12
type(num)
print (f'{num}')
print(f'type of fnum {type(fnum)} and snum {type(snum)}')
# Out:
# 12
# type of fnum <class 'int'> and snum <class 'int'>

# %%
my_num=12.44
type(my_num)
# Out:
# float

# %%
fnum=float(input('enter first number'))
snum=float(input('enter secound number'))
result=fnum+snum
print (f'Result after adding {fnum} and {snum} is =\t {result}')
# Out:
# enter first number2.2
# enter secound number3.3
# Result after adding 2.2 and 3.3 is =	 5.5

# %%
#BOOLEAN OR BOOL
is_active=True
type(is_active)
# Out:
# bool

# %%
is_active=False
type(is_active)
# Out:
# bool

# %%
print(f'Is active User?, {is_active}')
# Out:
# Is active User?, False

# %%
print(f'Is active User?, is_active')
# Out:
# Is active User?, is_active

# %%
#Binary Values
byte_ex=b'hello'
type(byte_ex)
# Out:
# bytes

# %%
#complex type
complex_num=2+3j
print(complex_num)
type(complex_num)
# Out:
# (2+3j)
# complex

# %%
#sequence type
#list[]
list_ex={1,2,3,4,5}
type(list_ex)
# Out:
# set

# %%
list_ex={1,2,3,4,5}
print(list_ex)
type(list_ex)
# Out:
# {1, 2, 3, 4, 5}
# set

# %%
cars=['BMW,MINI COOPER,AUDI']
print(cars)
type(cars)
# Out:
# ['BMW,MINI COOPER,AUDI']
# list

# %%
cars=['BMW,MINI COOPER,AUDI']
print(f'type of car is = {(cars)}')
# Out:
# type of car is = ['BMW,MINI COOPER,AUDI']

# %%
#tuple
tuple_ex=(1,2,3,4,5)
print(tuple_ex)
type(tuple_ex)
# Out:
# (1, 2, 3, 4, 5)
# tuple

# %%
#dictionary
emp={
    "id":1,
    "name":"Aisyah",
    "salary":20000.77

}
print(emp)
type(emp)
# Out:
# {'id': 1, 'name': 'Aisyah', 'salary': 20000.77}
# dict

# %%
#set
set_ex={10,20,30,40,50}
print(set_ex)
type(set_ex)
# Out:
# {50, 20, 40, 10, 30}
# set

# %%
#range
range_ex=range(10)
print(range_ex)
type(range_ex)
# Out:
# range(0, 10)
# range

# %%
range_ex2=range(5,20)
print(range_ex2)
type(range_ex2)
# Out:
# range(5, 20)
# range
