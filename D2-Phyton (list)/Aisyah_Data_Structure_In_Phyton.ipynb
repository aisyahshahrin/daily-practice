# %% [markdown]
# List in Python

# %%
emps=['sam','shah','is',12,14,True,None,12.55]

# %%
print(emps)
# Out:
# ['sam', 'shah', 'is', 12, 14, True, None, 12.55]

# %%
#indexing start from 0 and goes upto len-1
#len=number of item in list
print('number of items in list : ',len(emps))
# Out:
# number of items in list :  8

# %%
colour=['red','yellow','green']

# %%
print('Number of Item In List : ',len(colour))
# Out:
# Number of Item In List :  3

# %%
print('all Colours')
for colour_item in colour:
  print(f'color:{colour_item} is color and appear : {colour.count(colour_item)}times')
# Out:
# all Colours
# color:red is color and appear : 1times
# color:yellow is color and appear : 1times
# color:green is color and appear : 1times

# %%
actors=['Salman Khan','Sharukh Khan','Amir Khan','Amitabh','Ranbir Kappor','Vin Disel','Leo']

# %%
print('number of actors in list are: ', len(actors))
for actor in actors :
  print(actor)
# Out:
# number of actors in list are:  7
# Salman Khan
# Sharukh Khan
# Amir Khan
# Amitabh
# Ranbir Kappor
# Vin Disel
# Leo

# %%
for i in range(len(actors)):
  print(f'{i}-->{actors[i]}')
# Out:
# 0-->Salman Khan
# 1-->Sharukh Khan
# 2-->Amir Khan
# 3-->Amitabh
# 4-->Ranbir Kappor
# 5-->Vin Disel
# 6-->Leo

# %%
print(actors[5])
# Out:
# Vin Disel

# %%
print('number of actors:' , len(actors))

for(i,actor) in enumerate(actors):
  print(f'{i+1}. {actor}')
# Out:
# number of actors: 7
# 1. Salman Khan
# 2. Sharukh Khan
# 3. Amir Khan
# 4. Amitabh
# 5. Ranbir Kappor
# 6. Vin Disel
# 7. Leo

# %%
print('number of actors:' , len(actors))

for(i,actor) in enumerate(actors):
  print(f'{i+1}. {actor}')

# %% [markdown]
# baiki ups

# %%
cars=['BMW','Tesla','Honda','Proton','Toyota','Tata']

# %%
print('number of car brand in list are:', len(cars))
for i in range(len(cars)):
  print(f'{i+1}-->{cars[i]}')
# Out:
# number of car brand in list are: 6
# 1-->BMW
# 2-->Tesla
# 3-->Honda
# 4-->Proton
# 5-->Toyota
# 6-->Tata

# %%
actors=['Salman Khan','Sharukh Khan','Amir Khan','Amitabh','Ranbir Kappor','Vin Disel','Leo']

# %%
print(actors)
# Out:
# ['Salman Khan', 'Sharukh Khan', 'Amir Khan', 'Amitabh', 'Ranbir Kappor', 'Vin Disel', 'Leo']

# %%
#list slicing
print(actors[1:4])
# Out:
# ['Sharukh Khan', 'Amir Khan', 'rajit']

# %%
print('Insert actor after 3rd Position')
actors.insert(3,'rajit')
# Out:
# Insert actor after 3rd Position

# %% [markdown]
# print(actors)

# %%
print('First Three actors')
print(actors[:3])
# Out:
# First Three actors
# ['Salman Khan', 'Sharukh Khan', 'Amir Khan']

# %%
print('all actors starting from 3 to last')
print(actors[3:])
# Out:
# all actors starting from 3 to last
# ['rajit', 'Amitabh', 'Ranbir Kappor', 'Vin Disel', 'Leo']

# %%
print('last three items from actors')
print(actors[-3:])
# Out:
# last three items from actors
# ['Ranbir Kappor', 'Vin Disel', 'Leo']

# %%
#pop() to remove item from end of the list
actors.pop()
# Out:
# 'Leo'

# %%
print('list after pop')
print(actors)
# Out:
# list after pop
# []

# %%
#delete all items
actors.clear()

# %%
print('number of actors in the list: ', len(actors))
print(actors)
# Out:
# number of actors in the list:  0
# []

# %%
print('After re running the list')
print(actors)
# Out:
# After re running the list
# ['Salman Khan', 'Sharukh Khan', 'Amir Khan', 'Amitabh', 'Ranbir Kappor', 'Vin Disel', 'Leo']

# %%
print(Reverse)

# %%
list_number=[100,200,300,400,500]

# %%
print('number of items in list: \t' ,len(list_number))
print('maximum number in list : \t', (max(list_number)))
print('minimum number in list : \t' , (min(list_number)))
print('sum of all number in list : \t ',(sum(list_number)))
# Out:
# number of items in list: 	 5
# maximum number in list : 	 500
# minimum number in list : 	 100
# sum of all number in list : 	  1500

# %%
for (i,number) in enumerate(list_number):
  print(f'{i+1}. {number}')
# Out:
# 1. 100
# 2. 200
# 3. 300
# 4. 400
# 5. 500

# %%
for i in range(len(list_number)):
  print(f'{i+1}. {list_number[i]}')
# Out:
# 1. 100
# 2. 200
# 3. 300
# 4. 400
# 5. 500

# %%
print(list_number)
# Out:
# [100, 200, 300, 400, 500]

# %%
list_number.pop()
# Out:
# 500

# %%
#add item at the end of the list
list_number.append(600)

# %% [markdown]
# CONTINUE THE REST UPS

# %%
shopping_cart=[]

# %%
choice='y'
while(choice=='y'):
  item=input('Enter Item to the cart: ')
  shopping_cart.append(item)
  choice=(input('Do you want to add more items? (y,n): ')).lower()


  print('your shopping cart contains:')
  for item in shopping_cart:
    print(item)
# Out:
# Enter Item to the cart: sugar
# Do you want to add more items? (y,n): n
# your shopping cart contains:
# timun
# sugar
# kopi
# n
# sugar
# sugar
