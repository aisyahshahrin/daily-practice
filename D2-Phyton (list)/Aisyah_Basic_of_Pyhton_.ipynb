# %%
age=int(input('enter your age'))
if(age>=18):
    print('you are eligible for voting')
else:
    print('you are not eligible for voting')

print('your age is', age)
# Out:
# enter your age18
# you are eligible for voting
# your age is 18

# %%
marks=int(input('enter your marks'))
if(marks>=50):
    print('Congrats you did it!')
else:
    print('Sorry you are fail out of services please try again later')

print('Your marks is', marks)

# %%
#mp-marks percentage

mp=float (input('enter your marks w/o %'))

if(mp>89):
  grade='A'
elif(mp>70):
  grade='B'
elif(mp>50):
  grade='C'
elif(mp>40):
  grade='D'
else:
  grade='F'

print(f'Your grade is {grade} marks {mp}')

# %%
#number_user

nu=int (input('enter your number'))

if(nu>0):
  number='positif'
elif(nu<0):
  number='negatif'
elif(nu==0):
  number='nol'

print(f'number {number} marks {nu}')

# %%
number=int(input('enter your number'))
if(number>0):
  print(f'Number:  {number} is +{number}')
elif(number<0):
  print(f'number: {number} is -{number}')
else:
  print(f'number: {number} is Zero')

# %% [markdown]
# Loop: for, while

# %%
for num in range(10):
  print(num,end='\t')

# %%
#range (start,stop,setp)
for num in range(1,11,2):
  print(num,end='\t')

# %%
for num in range(0,100,10):
  print(num,end=' ')

# %%
given_number= int(input('enter your number to find out the sifir'))
print(f'table of {given_number}')
for num in range(1,11):
  print(f'{given_number}*{num}={given_number*num}')

# %%
given_number= int(input('enter your number to find out the sifir'))
print(f'table of {given_number}')
for num in range(1,11):
  print(f'{given_number}+{num}={given_number+num}')

# %%
list_car=['honda,BMW,Audi']

# %%
print('all cars in list as follow!!!')
for car in list_car:
  print(car)

# %% [markdown]
# while(condition)

# %%
num=10
while(num>0):
  print(num,end='\t')
  num -=1 #num=num-1

# %%
num=10
while(num>0):
  print(num,end='\t')
  num+=1
  print()

# %%
num=10
while(num<100):
  print(num,end='\t')
  num+=1
  print('end of loop')

# %%
#continue: skip that particular iteration adn loop will continue after that

for i in range(1,100):
  if (i%5==0):
   continue

print(i,end='\t')

# %%
#break:it will breakdown the loop
for i in range(1,100):
 if (i%5==0):
   break

 print(i,end='\t')

# %%
choice='y'
while(choice=='y'):
 given_number= int(input('enter your number:\t'))
 print(f'table of {given_number}')
 for num in range(1,11):
  print(f'{given_number}*{num}={given_number*num}')
 choice=input('Do you want to continue (y/n):\t').lower()

# %%
atm_pin=1234
allowed_attempts=3

while(allowed_attempts!=0):
  user_pin=int(input('enter your pin:\t'))
  if(user_pin==atm_pin):
    print('welcome to ATM')
    break

  else:
    allowed_attempts-=1
    if(allowed_attempts==0):
      print('your card has been blocked')
    else:
      print('wrong Pin Try Again')

# %%
atm_pin=1234
allowed_attempts=3

while(allowed_attempts!=0):
  user_pin=int(input('enter your pin:\t'))
  if(user_pin==atm_pin):
    print('welcome to ATM')
    break

  else:
    allowed_attempts-=1
    if(allowed_attempts==0):
      print('your card has been blocked')
    else:
      print('wrong Pin Try Again')

# %%
#cara 1
hidden_number=7
allowed_attempts=3

while(allowed_attempts!=0):
  user_pin=int(input('guess the number:\t'))
  if(user_pin==hidden_number):
    print('Correct answer You Have Won')
    break
  else:
    allowed_attempts-=1

  if(allowed_attempts==0):
      print('your have lost all your attempts')
  else:
    if(user_pin < hidden_number):
      print('Too Low')
    else: # user_pin > hidden_number
      print('Too High')
# Out:
# guess the number:	2
# Too Low
# guess the number:	9
# Too High
# guess the number:	7
# Correct answer You Have Won

# %%
#cara 2
hidden_number=7
allowed_attempts=3

while(allowed_attempts!=0):
  user_pin=int(input('guess the number:\t'))
  if(user_pin==hidden_number):
    print('Correct answer You Have Won')
    break
  else:
    allowed_attempts-=1

  if(allowed_attempts==0):
      print('your have lost all your attempts')
  else:
    if(user_pin < hidden_number):
      print('Too Low')
    else: # user_pin > hidden_number
      print('Too High')
# Out:
# guess the number:	2
# Too Low
# guess the number:	9
# Too High
# guess the number:	7
# Correct answer You Have Won
